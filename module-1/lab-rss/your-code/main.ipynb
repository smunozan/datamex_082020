# %% [markdown]
# # Working with RSS Feeds Lab
#
# Complete the following set of exercises to solidify your knowledge of parsing RSS feeds and extracting information from them.

# %%
import feedparser

# %% [markdown]
# ### 1. Use feedparser to parse the following RSS feed URL.

# %%
url = 'http://feeds.feedburner.com/oreilly/radar/atom'

# %%
data = feedparser.parse(url)

# %% [markdown]
# ### 2. Obtain a list of components (keys) that are available for this feed.

# %%
data.keys()
# Out:
# dict_keys(['feed', 'entries', 'bozo', 'headers', 'etag', 'updated', 'updated_parsed', 'href', 'status', 'encoding', 'version', 'namespaces'])

# %% [markdown]
# ### 3. Obtain a list of components (keys) that are available for the *feed* component of this RSS feed.

# %%
data["feed"].keys()
# Out:
# dict_keys(['title', 'title_detail', 'links', 'link', 'subtitle', 'subtitle_detail', 'updated', 'updated_parsed', 'language', 'sy_updateperiod', 'sy_updatefrequency', 'generator_detail', 'generator', 'feedburner_info', 'geo_lat', 'geo_long', 'feedburner_emailserviceid', 'feedburner_feedburnerhostname'])

# %% [markdown]
# ### 4. Extract and print the feed title, subtitle, author, and link.

# %%
feed_title = data["feed"]["title"]
feed_subtitle = data["feed"]["subtitle"]
#feed_author = data["feed"]["author"] 
feed_link = data["feed"]["link"]

print("Titulo:",feed_title)
print("Subtítulo:",feed_subtitle)
print("Autor:","No autor") #El feed no tiene autor, cada una de las entries tiene su autor.
print("Link:",feed_link)
# Out:
# Titulo: Radar
# Subtítulo: Now, next, and beyond: Tracking need-to-know trends at the intersection of business and technology
# Autor: No autor
# Link: https://www.oreilly.com/radar

# %% [markdown]
# ### 5. Count the number of entries that are contained in this RSS feed.

# %%
entries = data["entries"]

len(entries)
# Out:
# 60

# %% [markdown]
# ### 6. Obtain a list of components (keys) available for an entry.
#
# *Hint: Remember to index first before requesting the keys*

# %%
data["entries"][0].keys()
# Out:
# dict_keys(['title', 'title_detail', 'links', 'link', 'comments', 'published', 'published_parsed', 'authors', 'author', 'author_detail', 'tags', 'id', 'guidislink', 'summary', 'summary_detail', 'content', 'wfw_commentrss', 'slash_comments', 'feedburner_origlink'])

# %% [markdown]
# ### 7. Extract a list of entry titles.

# %%
titles = []

for i in data["entries"]:
    titles.append(i["title"])
    
titles
# Out:
# ['Four Short Links: 19 August 2020',
#  'Why Best-of-Breed is a Better Choice than All-in-One Platforms for Data Science',
#  'Four short links: 14 August 2020',
#  'The Least Liked Programming Languages',
#  'Four short links: 11 Aug 2020',
#  'Four short links: 7 Aug 2020',
#  'Four short links: 5 August 2020',
#  'Radar trends to watch: August 2020',
#  'Four short links: 31 July 2020',
#  'Four short links: 30 July 2020',
#  'Four short links: 29 July 2020',
#  'Bringing an AI Product to Market',
#  'Power, Harms, and Data',
#  'Four short links: 27 July 2020',
#  'Four short links: 24 July 2020',
#  'Four short links: 26 July 2020',
#  'Four short links: 22 July 2020',
#  'AI, Protests, and Justice',
#  'Four short links: 21 July 2020',
#  'Four short links: 20 July 2020',
#  'Four short links: 17 July 2020',
#  'Four short links: 16 July 2020',
#  'Microservices Adoption in 2020',
#  'Four short links: 15 July 2020',
#  'Society-Centered Design',
#  'Four short links: 14 July 2020',
#  'Four short links: 13 July 2020',
#  'Four short links: 10 July 2020',
#  'Automated Coding and the Future of Programming',
#  'Four short links: 9 July 2020',
#  'Four short links: 8 July 2020',
#  'Four short links: 7 July 2020',
#  'Four short links: 6 July 2020',
#  'Four short links: 3 July 2020',
#  'Four short links: 2 July 2020',
#  'Radar trends to watch: July 2020',
#  'Four short links: 1 July 2020',
#  'Four short links: 30 June 2020',
#  'Four short links: 29 June 2020',
#  'Four short links: 28 June 2020',
#  'Four short links: 25 June 2020',
#  'COVID-19 and Complex Systems',
#  'Four short links: 24 June 2020',
#  'Four short links: 23 June 2020',
#  'Four short links: 22 June 2020',
#  'Four short links: June 19, 2020',
#  'Four short links: 17 June 2020',
#  'Decision-Making in a Time of Crisis',
#  'Four short links: 16 June 2020',
#  'Four short links: 15 June 2020',
#  'Four short links: 12 June 2020',
#  'Four short links: 11 June 2020',
#  'Four short links: 10 June 2020',
#  'Machine Learning and the Production Gap',
#  'Four short links: 9 June 2020',
#  'Radar trends to watch: June 2020',
#  'Four short links: 8 June 2020',
#  'Four short links: 5 June 2020',
#  'Four short links: 4 June 2020',
#  'The Business of Open Source']

# %% [markdown]
# ### 8. Calculate the percentage of "Four short links" entry titles.

# %%
count = 0

for i in titles:
    if i.startswith("Four short links"):
        count += 1
        
perc = (count/len(titles))*100
print(f"El porcentaje es {perc}%")
# Out:
# El porcentaje es 73.33333333333333%

# %% [markdown]
# ### 9. Create a Pandas data frame from the feed's entries.

# %%
import pandas as pd
import re

# %%
entries =[]

for i in data["entries"]:
    
    title = i["title"]
    date = i["published"]
    authors = i["author"]
    summary = i['summary']
    summary = re.sub("\[?&#\d+;]?","",summary)

    entry={"Title":title,"Date":date,"Authors":authors,"Summary":summary}
    entries.append(entry)

# %%
entries_pd = pd.DataFrame(entries)
entries_pd
# Out:
#                                                 Title  \
# 0                    Four Short Links: 19 August 2020
# 1   Why Best-of-Breed is a Better Choice than All-...
# 2                    Four short links: 14 August 2020
# 3               The Least Liked Programming Languages
# 4                       Four short links: 11 Aug 2020
# 5                        Four short links: 7 Aug 2020
# 6                     Four short links: 5 August 2020
# 7                  Radar trends to watch: August 2020
# 8                      Four short links: 31 July 2020
# 9                      Four short links: 30 July 2020
# 10                     Four short links: 29 July 2020
# 11                   Bringing an AI Product to Market
# 12                             Power, Harms, and Data
# 13                     Four short links: 27 July 2020
# 14                     Four short links: 24 July 2020
# 15                     Four short links: 26 July 2020
# 16                     Four short links: 22 July 2020
# 17                          AI, Protests, and Justice
# 18                     Four short links: 21 July 2020
# 19                     Four short links: 20 July 2020
# 20                     Four short links: 17 July 2020
# 21                     Four short links: 16 July 2020
# 22                     Microservices Adoption in 2020
# 23                     Four short links: 15 July 2020
# 24                            Society-Centered Design
# 42                                    Nat Torkington
# 43                                    Nat Torkington
# 44                                    Nat Torkington
# 45                                    Nat Torkington
# 46                                    Nat Torkington
# 47                               Hugo Bowne-Anderson
# 48                                    Nat Torkington
# 49                                    Nat Torkington
# 50                                    Nat Torkington
# 51                                    Nat Torkington
# 52                                    Nat Torkington
# 53                                     Mike Loukides
# 54                                    Nat Torkington
# 55                                     Mike Loukides
# 56                                    Nat Torkington
# 57                                    Nat Torkington
# 58                                    Nat Torkington
# 59      Adam Jacob, Nat Torkington and Mike Loukides
#
#                                               Summary
# 0   The Design Space of Computational Notebooks  L...
# 1   So you need to redesign your company’s data in...
# 2   Sinter  Sinter uses the user-mode EndpointSecu...
# 3   StackOverflows 2020 developer survey included ...
# 4   ImmuDB  lightweight, high-speed immutable data...
# 5   Surprising Economics of Load-Balanced Systems ...
# 6   Tales of the Autistic Developer  Senior Develo...
# 7   I thought July was going to be a dull month, b...
# 8   Migrating a 40TB SQL Server Database  A horror...
# 9   Turning the IDE Inside Out with Datalog  tl;dr...
# 10  The Golden Rule of Software Quality  Prefer to...
# 11  The Core Responsibilities of the AI Product Ma...
# 12  A recent article in The Verge discussed PULSE,...
# 13  Tech Regulation  ‘Tech’, of course, has all of...
# 14  How Taiwans Unlikely Digital Minister Hacked t...
# 15  As We May Code  why aren’t we — ostensibly the...
# 16  wiki.js  Portable open-source Javascript featu...
# 17  Largely on the impetus of the Black Lives Matt...
# 18  22 Principles for Great Product Managers  This...
# 19  A Bug-Sized Camera for Bug-Sized Robots and Bu...
# 20  Matters Computational: Ideas, Algorithms, Sour...
# 21  Pseudogen  [open source] tool to automatically...
# 22  Microservicesseem to be everywhere. Scratch th...
# 23  Fixing Bugs Properly  Why did a fix that seems...
# 24  A World of Individuals Our world is on fire. F...
# 25  Neutralizing Misinformation through Inoculatio...
# 26  Too Efficiency  (Tim Bray) Think of efficiency...
# 27  Notes on Splicing CRDTs for Structured Hyperte...
# 28  At Microsofts Build conference, Microsoft CTO ...
# 29  Avoiding Fallback in Distributed Systems  In t...
# 30  When Data is Messy  I love stories that illust...
# 31  eDEX-ui  a fullscreen, cross-platform terminal...
# 32  Debubble  I like that people are trying softwa...
# 33  Open Differential Privacy  Open source softwar...
# 34  Sweetviz  an open source Python library that g...
# 35  News of the past month is dominated by COVID-1...
# 36  PyLance  Python language server for VS Code th...
# 37  Durable Teams  Rael Dornfest called this proje...
# 38  Why Does DARPA Work?  Absolutely the best thin...
# 39  timecraft  synthesizing time lapse videos depi...
# 40  Krita  a professional FREE and open source pai...
# 41  In various mailing lists about the COVID-19 pa...
# 42  Youve Been Referred Here Because Youre Wrong A...
# 43  Work From Home Cybersecurity Course  Secure yo...
# 44  Root Causes  here are a set of “root causes” t...
# 45  Tsunami  a general purpose network security sc...
# 46  Drive and Listen  Video of driving through a c...
# 47  In the 1996 cult classic film Swingers, two fr...
# 48  The Global Implications of “Re-education” Tech...
# 49  Team Players: How Social Skills Improve Group ...
# 50  OpenSHC  Syropod High-level Controller (SHC) i...
# 51  Testing the Automation Revolution Hypothesis  ...
# 52  CapRover  an extremely easy to use app/databas...
# 53  The biggest problem facing machine learning to...
# 54  Anti-Monopoly Thinking  Tim Bray reviews The M...
# 55  Most of the technical news this month continue...
# 56  Privacy Threats in Intimate Relationships  Thi...
# 57  Computers Barely Work  An interview with Greg ...
# 58  Ears to Faces  our goal is to generate a front...
# 59  In a recent Twitter thread, Adam Jacob (co-fou...

# %% [markdown]
# ### 10. Count the number of entries per author and sort them in descending order.

# %%
entries_pd["Authors"].value_counts()
# Out:
# Nat Torkington                                      45
# Mike Loukides                                        9
# Mike Loukides and Steve Swoyer                       1
# Hugo Bowne-Anderson                                  1
# Sarah Gold                                           1
# Justin Norman, Peter Skomoroch and Mike Loukides     1
# Matthew Rocklin and Hugo Bowne-Anderson              1
# Adam Jacob, Nat Torkington and Mike Loukides         1
# Name: Authors, dtype: int64

# %% [markdown]
# ### 11. Add a new column to the data frame that contains the length (number of characters) of each entry title. Return a data frame that contains the title, author, and title length of each entry in descending order (longest title length at the top).

# %%
entries_pd["Title Length"] = entries_pd["Title"].apply(lambda x: len(x))
entries_pd_2 = entries_pd[["Title","Authors","Title Length"]]

entries_pd_2.sort_values(by=['Title Length'],ascending=False)
# Out:
#                                                 Title  \
# 1   Why Best-of-Breed is a Better Choice than All-...
# 28     Automated Coding and the Future of Programming
# 53            Machine Learning and the Production Gap
# 3               The Least Liked Programming Languages
# 47                Decision-Making in a Time of Crisis
# 7                  Radar trends to watch: August 2020
# 0                    Four Short Links: 19 August 2020
# 11                   Bringing an AI Product to Market
# 2                    Four short links: 14 August 2020
# 35                   Radar trends to watch: July 2020
# 55                   Radar trends to watch: June 2020
# 45                    Four short links: June 19, 2020
# 6                     Four short links: 5 August 2020
# 8                      Four short links: 31 July 2020
# 9                      Four short links: 30 July 2020
# 44                     Four short links: 22 June 2020
# 43                     Four short links: 23 June 2020
# 42                     Four short links: 24 June 2020
# 40                     Four short links: 25 June 2020
# 39                     Four short links: 28 June 2020
# 38                     Four short links: 29 June 2020
# 37                     Four short links: 30 June 2020
# 48                     Four short links: 16 June 2020
# 49                     Four short links: 15 June 2020
# 50                     Four short links: 12 June 2020
# 51                     Four short links: 11 June 2020
# 52                     Four short links: 10 June 2020
# 13                     Four short links: 27 July 2020
# 23                     Four short links: 15 July 2020
# 27                     Four short links: 10 July 2020
# 26                     Four short links: 13 July 2020
# 14                     Four short links: 24 July 2020
# 15                     Four short links: 26 July 2020
# 16                     Four short links: 22 July 2020
# 10                     Four short links: 29 July 2020
# 18                     Four short links: 21 July 2020
# 19                     Four short links: 20 July 2020
# 20                     Four short links: 17 July 2020
# 21                     Four short links: 16 July 2020
# 22                     Microservices Adoption in 2020
# 46                     Four short links: 17 June 2020
# 25                     Four short links: 14 July 2020
# 57                      Four short links: 5 June 2020
# 58                      Four short links: 4 June 2020
# 54                      Four short links: 9 June 2020
# 56                      Four short links: 8 June 2020
# 30                      Four short links: 8 July 2020
# 36                      Four short links: 1 July 2020
# 34                      Four short links: 2 July 2020
# 33                      Four short links: 3 July 2020
# 32                      Four short links: 6 July 2020
# 31                      Four short links: 7 July 2020
# 29                      Four short links: 9 July 2020
# 4                       Four short links: 11 Aug 2020
# 41                       COVID-19 and Complex Systems
# 5                        Four short links: 7 Aug 2020
# 59                        The Business of Open Source
# 17                          AI, Protests, and Justice
# 24                            Society-Centered Design
# 12                             Power, Harms, and Data
#
#                                              Authors  Title Length
# 1            Matthew Rocklin and Hugo Bowne-Anderson            79
# 28                                     Mike Loukides            46
# 53                                     Mike Loukides            39
# 3                                      Mike Loukides            37
# 47                               Hugo Bowne-Anderson            35
# 7                                      Mike Loukides            34
# 0                                     Nat Torkington            32
# 11  Justin Norman, Peter Skomoroch and Mike Loukides            32
# 2                                     Nat Torkington            32
# 35                                     Mike Loukides            32
# 55                                     Mike Loukides            32
# 45                                    Nat Torkington            31
# 6                                     Nat Torkington            31
# 8                                     Nat Torkington            30
# 9                                     Nat Torkington            30
# 44                                    Nat Torkington            30
# 43                                    Nat Torkington            30
# 42                                    Nat Torkington            30
# 40                                    Nat Torkington            30
# 39                                    Nat Torkington            30
# 38                                    Nat Torkington            30
# 37                                    Nat Torkington            30
# 48                                    Nat Torkington            30
# 49                                    Nat Torkington            30
# 50                                    Nat Torkington            30
# 51                                    Nat Torkington            30
# 52                                    Nat Torkington            30
# 13                                    Nat Torkington            30
# 23                                    Nat Torkington            30
# 27                                    Nat Torkington            30
# 26                                    Nat Torkington            30
# 14                                    Nat Torkington            30
# 15                                    Nat Torkington            30
# 16                                    Nat Torkington            30
# 10                                    Nat Torkington            30
# 18                                    Nat Torkington            30
# 19                                    Nat Torkington            30
# 20                                    Nat Torkington            30
# 21                                    Nat Torkington            30
# 22                    Mike Loukides and Steve Swoyer            30
# 46                                    Nat Torkington            30
# 25                                    Nat Torkington            30
# 57                                    Nat Torkington            29
# 58                                    Nat Torkington            29
# 54                                    Nat Torkington            29
# 56                                    Nat Torkington            29
# 30                                    Nat Torkington            29
# 36                                    Nat Torkington            29
# 34                                    Nat Torkington            29
# 33                                    Nat Torkington            29
# 32                                    Nat Torkington            29
# 31                                    Nat Torkington            29
# 29                                    Nat Torkington            29
# 4                                     Nat Torkington            29
# 41                                     Mike Loukides            28
# 5                                     Nat Torkington            28
# 59      Adam Jacob, Nat Torkington and Mike Loukides            27
# 17                                     Mike Loukides            25
# 24                                        Sarah Gold            23
# 12                                     Mike Loukides            22

# %% [markdown]
# ### 12. Create a list of entry titles whose summary includes the phrase "machine learning."

# %%
ml_lst = []

prueba = entries_pd.apply(lambda x: ml_lst.append(x["Title"]) if "machine learning" in x["Summary"] else False, axis=1)

ml_lst
# Out:
# ['Four short links: 8 July 2020', 'Machine Learning and the Production Gap']
