# %% [markdown]
# # Parallelization Lab
#
# In this lab, you will be leveraging several concepts you have learned to obtain a list of links from a web page and crawl and index the pages referenced by those links - both sequentially and in parallel. Follow the steps below to complete the lab.

# %% [markdown]
# ## Step 1: Use the requests library to retrieve the content from the URL below.

# %%
import requests

url = 'https://en.wikipedia.org/wiki/Data_science'

# %%
resp = requests.get(url)

# %% [markdown]
# ## Step 2: Use BeautifulSoup to extract a list of all the unique links on the page.

# %%
from bs4 import BeautifulSoup as bs

# %%
sopa = bs(resp.content, "html.parser")
a_lst = sopa.findAll("a")
links_lst = []

for i in a_lst:
    try:
        href = i["href"]
        if href.startswith("/") or href.startswith("h"):
            links_lst.append(href)
    except:
        pass

# %% [markdown]
# ## Step 3: Use list comprehensions with conditions to clean the link list.
#
# There are two types of links, absolute and relative. Absolute links have the full URL and begin with http while relative links begin with a forward slash (/) and point to an internal page within the wikipedia.org domain. Clean the respective types of URLs as follows.
#
# - Absolute Links: Create a list of these and remove any that contain a percentage sign (%).
# - Relativel Links: Create a list of these, add the domain to the link so that you have the full URL, and remove any that contain a percentage sign (%).
# - Combine the list of absolute and relative links and ensure there are no duplicates.

# %%
domain = 'http://wikipedia.org'

# %%
abs_links = [i for i in links_lst if i.startswith("h") and "%" not in i]
rel_links = [domain+i for i in links_lst if i.startswith("/") and "%" not in i]

links = list(set(abs_links+rel_links))
links
# Out:
# ['https://arxiv.org/list/cs.LG/recent',
#  'http://wikipedia.org/wiki/Learning_to_rank',
#  'https://www.wired.com/2014/07/a-drag-and-drop-toolkit-that-lets-anyone-create-interactive-maps/',
#  'http://wikipedia.org/wiki/Nate_Silver',
#  'http://wikipedia.org/wiki/Category:All_lists_having_no_precise_inclusion_criteria',
#  'http://wikipedia.org/wiki/Plotly',
#  'http://wikipedia.org/wiki/Data_(computing)',
#  'http://wikipedia.org/wiki/Boosting_(machine_learning)',
#  'https://magazine.amstat.org/blog/2015/10/01/asa-statement-on-the-role-of-statistics-in-data-science/',
#  'http://wikipedia.org/wiki/Hierarchical_clustering',
#  'http://wikipedia.org/wiki/Knowledge',
#  'https://web.archive.org/web/20170320193019/https://books.google.com/books?id=oGs_AQAAIAAJ',
#  'http://wikipedia.org/w/index.php?title=Data_science&action=edit&section=9',
#  'http://wikipedia.org/wiki/Self-organizing_map',
#  'http://wikipedia.org/wiki/Data_management',
# ...

# %% [markdown]
# ## Step 4: Use the os library to create a folder called *wikipedia* and make that the current working directory.

# %%
import os

# %%
os.mkdir("wikipedia2")

# %% [markdown]
# ## Step 5: Write a function called index_page that accepts a link and does the following.
#
# - Tries to request the content of the page referenced by that link.
# - Slugifies the filename using the `slugify` function from the [python-slugify](https://pypi.org/project/python-slugify/) library and adds a .html file extension.
#     - If you don't already have the python-slugify library installed, you can pip install it as follows: `$ pip install python-slugify`.
#     - To import the slugify function, you would do the following: `from slugify import slugify`.
#     - You can then slugify a link as follows `slugify(link)`.
# - Creates a file in the wikipedia folder using the slugified filename and writes the contents of the page to the file.
# - If an exception occurs during the process above, just `pass`.

# %%
from slugify import slugify

# %%
resp = requests.get("https://cran.r-project.org/doc/FAQ/R-FAQ.html#What-is-R_003f")
sopa = bs(resp.content,"html.parser")
with open(f"prueba.html", 'wb') as f:
    f.write(sopa.encode(formatter=None))

# %%
def index_page(link):
    try:
        resp = requests.get(link)
        sopa = bs(resp.content, "html.parser")
        filename = slugify(link)
        with open(f"wikipedia/{filename}.html", 'wb') as f:
            f.write(sopa.encode(formatter=None))
        return
    except:
        pass

# %% [markdown]
# ## Step 6: Sequentially loop through the list of links, running the index_page function each time.
#
# Remember to include `%%time` at the beginning of the cell so that it measures the time it takes for the cell to run.

# %%
# %%time

for i in links:
    index_page(i)
# Out:
# Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# CPU times: user 1min 15s, sys: 1.99 s, total: 1min 17s
# Wall time: 4min

# %% [markdown]
# ## Step 7: Perform the page indexing in parallel and note the difference in performance.
#
# Remember to include `%%time` at the beginning of the cell so that it measures the time it takes for the cell to run.

# %%
from multiprocessing import Pool

# %%
nums = [1,2,3,4,5]

# %%
# %%time

from multiprocessing import Pool
import index_func

if __name__ ==  '__main__': 
 num_processors = 3
 p=Pool(processes = num_processors)
 output = p.map(index_func.index_page,links)
 print(output)
# Out:
# ['error', 'error', 'error', 'error', 'error', 'error', 'error', 'error', 'error', 'error', 'error', 'error', 'error', 'error', 'error', 'error', 'error', 'error', 'error', 'error', 'error', 'error', 'error', 'error', 'error', 'error', 'error', 'error', 'error', 'error', 'error', 'error', 'error', 'error', 'error', 'error', 'error', 'error', 'error', 'error', 'error', 'error', 'error', 'error', 'error', 'error', 'error', 'error', 'error', 'error', 'error', 'error', 'error', 'error', 'error', 'error', 'error', 'error', 'error', 'error', 'error', 'error', 'error', 'error', 'error', 'error', 'error', 'error', 'error', 'error', 'error', 'error', 'error', 'error', 'error', 'error', 'error', 'error', 'error', 'error', 'error', 'error', 'error', 'error', 'error', 'error', 'error', 'error', 'error', 'error', 'error', 'error', 'error', 'error', 'error', 'error', 'error', 'error', 'error', 'error', 'error', 'error', 'error', 'error', 'error', 'error', 'error', 'error', 'error', 'error', 'error'
# ...

# %%
import index_func

x = map(index_func.index_page,links)
list(x)
# Out:
# ['error',
#  'error',
#  'error',
#  'error',
#  'error',
#  'error',
#  'error',
#  'error',
#  'error',
#  'error',
#  'error',
#  'error',
#  'error',
#  'error',
#  'error',
#  'error',
#  'error',
#  'error',
#  'error',
#  'error',
#  'error',
#  'error',
#  'error',
#  'error',
#  'error',
#  'error',
#  'error',
#  'error',
#  'error',
#  'error',
#  'error',
#  'error',
#  'error',
#  'error',
#  'error',
#  'error',
#  'error',
#  'error',
#  'error',
#  'error',
#  'error',
#  'error',
#  'error',
#  'error',
#  'error',
#  'error',
#  'error',
#  'error',
#  'error',
#  'error',
#  'error',
#  'error',
#  'error',
#  'error',
#  'error',
#  'error',
#  'error',
#  'error',
#  'error',
#  'error',
#  'error',
#  'error',
#  'error',
#  'error',
#  'error',
#  'error',
#  'error',
#  'error',
#  'error',
#  'error',
#  'error',
#  'error',
#  'error',
#  'error',
#  'error',
#  'error',
#  'error',
#  'error',
#  'error',
#  'error',
#  'error',
#  'error',
#  'error',
# ...
